# %% [markdown]
# #Python
#
# 1.  What is Python, and why is it popular?
# -   Python is a popular, versatile, and easy-to-learn programming language widely used in web development, data science, machine learning, and more, due to its readability, extensive libraries, and a large, supportive community.
#
# 2.  What is an interpreter in Python ?
# -  In Python, an interpreter is a program that reads and executes Python code line by line, translating it into machine-readable instructions.
#
# 3.  What are pre-defined keywords in Python ?
# -  Keywords in Python are predefined reserved words with special meanings so the interpreter can understand them. They perform specific tasks in Python programming and are a part of its syntax.25 Feb 2025
#
# 4.  Can keywords be used as variable names ?
# -  no, you cannot use keywords as variable names in most programming languages because keywords are reserved words with specific meanings, and using them as variable names would lead to syntax errors.
#
# 5.   What is mutability in Python ?
# -   In Python, mutability refers to an object's ability to be changed after it's created; mutable objects can be modified, while immutable objects cannot.
#
# 6.  Why are lists mutable, but tuples are immutable ?
# -  Tuples and lists are the same in every way except two: tuples use parentheses instead of square brackets, and the items in tuples cannot be modified (but the items in lists can be modified). We often call lists mutable (meaning they can be changed) and tuples immutable (meaning they cannot be changed).
#
# 7.  What is the difference between “==” and “is” operators in Python ?
# -  the '==' is known as the equality operator. The 'is' is known as the identity operator. The == operator helps us compare the equality of objects. The is operator helps us check whether different variables point towards a similar object in the memory.
#
# 8.  What are logical operators in Python ?
# -   In Python, logical operators, and, or, and not, are used to combine or manipulate boolean expressions, resulting in a single boolean value (True or False).
#
# 9.   What is type casting in Python ?
# -   n Python, type casting (also known as type conversion) is the process of converting a variable's data type to another, either implicitly (automatically by Python) or explicitly (using built-in functions like int(), float(), str(), etc.).
#
# 10.  What is the difference between implicit and explicit type casting ?
# -    In programming, implicit type casting happens automatically by the compiler, while explicit type casting, also known as type casting, requires the programmer to explicitly instruct the conversion.
#
# 11. What is the purpose of conditional statements in Python ?
# -   Conditional statements in Python, like if, elif, and else, allow your code to make decisions and execute different blocks of code based on whether a condition is true or false, enabling dynamic and responsive programs.
#
# 12.  Conditional statements in Python, like if, elif, and else, allow your code to make decisions and execute different blocks of code based on whether a condition is true or false, enabling dynamic and responsive programs.
# -    The if... else statement in Python is used to control the flow of execution based on a condition. It allows the program to make decisions and execute different blocks of code based on whether the condition evaluates to True or False. The condition can be any expression that evaluates to either True or False.
#
# 13.   What is the difference between for and while loops  ?
# -     The main difference between for and while loops is how they determine when to stop iterating: for loops are best for iterating over a sequence or a known number of times, while while loops are used when the number of iterations is determined by a condition that must be met.
#
# 14.  Describe a scenario where a while loop is more suitable than a for loop.
# -   Use a for loop when you know the loop should execute n times. Use a while loop for reading a file into a variable. Use a while loop when asking for user input. Use a while loop when the increment value is nonstandard.25
#
#                                                                           practical questions
#
# 1.  Write a Python program to print "Hello, World!y .
# -   print("Hello, World!y")
#
# 2.  Write a Python program that displays your name and age.
# -   # Define name and age
# name = "Your Name"  # Replace with your actual name
# age = 25  # Replace with your actual age
#
# # Print name and age
# print("Name:", name)
# print("Age:", age)
#
# 3. Write code to print all the pre-defined keywords in Python using the keyword library.
# - import keyword
#
# # Print all Python keywords
# print(keyword.kwlist)
#
# 4.  Write a program that checks if a given word is a Python keyword.
# -   import keyword
#
# # Get user input
# word = input("Enter a word: ")
#
# # Check if it's a Python keyword
# if keyword.iskeyword(word):
#     print(f"'{word}' is a Python keyword.")
# else:
#     print(f"'{word}' is NOT a Python keyword.")
#
# 5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
# for each.
# -   # Creating a list (mutable)
# my_list = [1, 2, 3, 4]
# print("Original List:", my_list)
#
# # Modifying an element in the list
# my_list[1] = 20
# print("Modified List:", my_list)
#
# # Creating a tuple (immutable)
# my_tuple = (1, 2, 3, 4)
# print("Original Tuple:", my_tuple)
#
# # Attempting to modify an element in the tuple (this will raise an error)
# try:
#     my_tuple[1] = 20
# except TypeError as e:
#     print("Error:", e)
# Here's a demonstration of how modifying a list and a tuple works differently in Python:
#
# ```python
# # Creating a list (mutable)
# my_list = [1, 2, 3, 4]
# print("Original List:", my_list)
#
# # Modifying an element in the list
# my_list[1] = 20
# print("Modified List:", my_list)
#
# # Creating a tuple (immutable)
# my_tuple = (1, 2, 3, 4)
# print("Original Tuple:", my_tuple)
#
# # Attempting to modify an element in the tuple (this will raise an error)
# try:
#     my_tuple[1] = 20
# except TypeError as e:
#     print("Error:", e)
# ```
#
# ### Explanation:
# - **Lists** are **mutable**, meaning you can change their elements after creation.
# - **Tuples** are **immutable**, meaning you cannot modify their elements once they are created. Attempting to do so results in a `TypeError`. 🚀
#
# 6.  Write a function to demonstrate the behavior of mutable and immutable arguments.
# -   def modify_values(immutable_var, mutable_var):
#     # Trying to modify an immutable variable (int)
#     immutable_var += 10
#     print("Inside function (immutable):", immutable_var)
#
#     # Modifying a mutable variable (list)
#     mutable_var.append(100)
#     print("Inside function (mutable):", mutable_var)
#
#
# # Immutable argument (integer)
# num = 50
#
# # Mutable argument (list)
# my_list = [1, 2, 3]
#
# # Calling the function
# modify_values(num, my_list)
#
# # Printing values after function call
# print("Outside function (immutable):", num)  # Unchanged
# print("Outside function (mutable):", my_list)  # Changed
# Here's a Python program that demonstrates the behavior of **mutable** and **immutable** arguments in functions:
#
# ```python
# def modify_values(immutable_var, mutable_var):
#     # Trying to modify an immutable variable (int)
#     immutable_var += 10
#     print("Inside function (immutable):", immutable_var)
#
#     # Modifying a mutable variable (list)
#     mutable_var.append(100)
#     print("Inside function (mutable):", mutable_var)
#
#
# # Immutable argument (integer)
# num = 50
#
# # Mutable argument (list)
# my_list = [1, 2, 3]
#
# # Calling the function
# modify_values(num, my_list)
#
# # Printing values after function call
# print("Outside function (immutable):", num)  # Unchanged
# print("Outside function (mutable):", my_list)  # Changed
# ```
#
# ### Explanation:
# 1. **Immutable objects** (like integers, strings, and tuples) **do not change** when passed to a function. A new copy is created instead.
# 2. **Mutable objects** (like lists and dictionaries) **can be modified** inside a function, and the changes persist outside the function.
#
# 7.  Write a program that performs basic arithmetic operations on two user-input numbers.
# -   Here's a Python program that performs basic arithmetic operations on two user-input numbers:
#
# ```python
# # Get user input for two numbers
# num1 = float(input("Enter first number: "))
# num2 = float(input("Enter second number: "))
#
# # Perform arithmetic operations
# addition = num1 + num2
# subtraction = num1 - num2
# multiplication = num1 * num2
# division = num1 / num2 if num2 != 0 else "Undefined (division by zero)"
#
# # Display the results
# print("\nResults:")
# print(f"Addition: {num1} + {num2} = {addition}")
# print(f"Subtraction: {num1} - {num2} = {subtraction}")
# print(f"Multiplication: {num1} * {num2} = {multiplication}")
# print(f"Division: {num1} / {num2} = {division}")
# ```
#
# ### Features:
# - Takes two numbers as input.
# - Performs **addition, subtraction, multiplication, and division**.
# - Handles division by zero gracefully. 🚀Here's a Python program that performs basic arithmetic operations on two user-input numbers:
#
# ```python
# * {num2} = {multiplication}")
# print(f"Division: {num1} / {num2} = {division}")
# ``
# Here's a Python program that performs basic arithmetic operations on two user-input numbers:
#
# ```python
# ### Features:
# - Takes two numbers as input.
# - Performs **addition, subtraction, multiplication, and division**.
# - Handles division by zero gracefully. 🚀
#
# 8.   Write a program to demonstrate the use of logical operators.
# -   # Get user input
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
#
# # Logical AND
# print("\nLogical AND:")
# print(f"({a} > 0 and {b} > 0) =", (a > 0 and b > 0))  # True if both are positive
#
# # Logical OR
# print("\nLogical OR:")
# print(f"({a} > 0 or {b} > 0) =", (a > 0 or b > 0))  # True if at least one is positive
#
# # Logical NOT
# print("\nLogical NOT:")
# print(f"not({a} > 0) =", not(a > 0))  # True if a is not positive
# print(f"not({b} > 0) =", not(b > 0))  # True if b is not positive
# Here's a Python program to demonstrate the use of **logical operators** (`and`, `or`, `not`):
#
# ```python
# # Get user input
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
#
# # Logical AND
# print("\nLogical AND:")
# print(f"({a} > 0 and {b} > 0) =", (a > 0 and b > 0))  # True if both are positive
#
# # Logical OR
# print("\nLogical OR:")
# print(f"({a} > 0 or {b} > 0) =", (a > 0 or b > 0))  # True if at least one is positive
#
# # Logical NOT
# print("\nLogical NOT:")
# print(f"not({a} > 0) =", not(a > 0))  # True if a is not positive
# print(f"not({b} > 0) =", not(b > 0))  # True if b is not positive
# ```
#
# ### Explanation:
# - **`and`** returns `True` if **both conditions** are `True`.
# - **`or`** returns `True` if **at least one condition** is `True`.
# - **`not`** reverses the condition (i.e., `True` becomes `False`, and vice versa).
#
# 🚀 Try it out by entering different numbers!
#
# 9.  Write a Python program to convert user input from string to integer, float, and boolean types.
# -  # Get user input as a string
# user_input = input("Enter a value: ")
#
# # Convert to integer
# try:
#     int_value = int(user_input)
#     print("Integer:", int_value)
# except ValueError:
#     print("Cannot convert to Integer.")
#
# # Convert to float
# try:
#     float_value = float(user_input)
#     print("Float:", float_value)
# except ValueError:
#     print("Cannot convert to Float.")
#
# # Convert to boolean
# bool_value = bool(user_input)  # Any non-empty string converts to True
# print("Boolean:", bool_value)
# Here's a Python program that converts user input from a string to **integer, float, and boolean** types:
#
# ```python
# # Get user input as a string
# user_input = input("Enter a value: ")
#
# # Convert to integer
# try:
#     int_value = int(user_input)
#     print("Integer:", int_value)
# except ValueError:
#     print("Cannot convert to Integer.")
#
# # Convert to float
# try:
#     float_value = float(user_input)
#     print("Float:", float_value)
# except ValueError:
#     print("Cannot convert to Float.")
#
# # Convert to boolean
# bool_value = bool(user_input)  # Any non-empty string converts to True
# print("Boolean:", bool_value)
# ```
#
# ### Explanation:
# 1. **Integer Conversion** (`int(user_input)`) – Converts input to an integer if possible.
# 2. **Float Conversion** (`float(user_input)`) – Converts input to a floating-point number.
# 3. **Boolean Conversion** (`bool(user_input)`) – Converts input to `True` if it's non-empty; otherwise, `False`.
#
# 10. Write code to demonstrate type casting with list elements.
# -  # Sample list with string numbers
# str_list = ["10", "20", "30", "40.5", "50.8"]
#
# # Convert list elements to integers (if possible)
# int_list = [int(float(x)) for x in str_list]
# print("Integer List:", int_list)
#
# # Convert list elements to floats
# float_list = [float(x) for x in str_list]
# print("Float List:", float_list)
#
# # Convert list elements to booleans
# bool_list = [bool(x) for x in str_list]
# print("Boolean List:", bool_list)
# Here's a Python program that demonstrates **type casting** with list elements:
#
# ```python
# # Sample list with string numbers
# str_list = ["10", "20", "30", "40.5", "50.8"]
#
# # Convert list elements to integers (if possible)
# int_list = [int(float(x)) for x in str_list]
# print("Integer List:", int_list)
#
# # Convert list elements to floats
# float_list = [float(x) for x in str_list]
# print("Float List:", float_list)
#
# # Convert list elements to booleans
# bool_list = [bool(x) for x in str_list]
# print("Boolean List:", bool_list)
# ```
#
# ### Explanation:
# - **Integer Casting**: Converts string numbers to integers (handles decimals by converting them first to `float`).
# - **Float Casting**: Converts string numbers to floating-point values.
# - **Boolean Casting**: Converts elements to `True` (except empty strings, which become `False`).
#
# 11. Write a program that checks if a number is positive, negative, or zero.
# -   # Get user input
# num = float(input("Enter a number: "))
#
# # Check conditions
# if num > 0:
#     print("The number is Positive.")
# elif num < 0:
#     print("The number is Negative.")
# else:
#     print("The number is Zero.")
# Here's a Python program that checks if a number is **positive, negative, or zero**:
#
# ```python
# # Get user input
# num = float(input("Enter a number: "))
#
# # Check conditions
# if num > 0:
#     print("The number is Positive.")
# elif num < 0:
#     print("The number is Negative.")
# else:
#     print("The number is Zero.")
# ```
#
# ### Explanation:
# - If `num > 0`, it's **positive**.
# - If `num < 0`, it's **negative**.
# - If `num == 0`, it's **zero**.
#
# 12. Write a for loop to print numbers from 1 to 10.
# -  for num in range(1, 11):
#     print(num)
# Here's a simple **for loop** to print numbers from **1 to 10**:
#
# ```python
# for num in range(1, 11):
#     print(num)
# ```
#
# ### Explanation:
# - `range(1, 11)` generates numbers from `1` to `10` (excluding `11`).
# - The `for` loop iterates through each number and prints it.
#
# 13. Write a Python program to find the sum of all even numbers between 1 and 50.
# -  # Using a for loop to sum even numbers
# even_sum = sum(num for num in range(1, 51) if num % 2 == 0)
#
# # Print the result
# print("Sum of even numbers between 1 and 50:", even_sum)
# Here's a Python program to find the **sum of all even numbers** between **1 and 50**:
#
# ```python
# # Using a for loop to sum even numbers
# even_sum = sum(num for num in range(1, 51) if num % 2 == 0)
#
# # Print the result
# print("Sum of even numbers between 1 and 50:", even_sum)
# ```
#
# ### Explanation:
# - The `range(1, 51)` generates numbers from **1 to 50**.
# - The condition `if num % 2 == 0` filters **even numbers**.
# - The `sum()` function calculates their total.
#
# 14. Write a program to reverse a string using a while loop.
# -   # Get user input
# string = input("Enter a string: ")
#
# # Initialize variables
# reversed_string = ""
# index = len(string) - 1  # Start from the last character
#
# # Reverse the string using a while loop
# while index >= 0:
#     reversed_string += string[index]
#     index -= 1  # Move to the previous character
#
# # Print the reversed string
# print("Reversed String:", reversed_string)
# Here's a Python program to **reverse a string** using a **while loop**:
#
# ```python
# # Get user input
# string = input("Enter a string: ")
#
# # Initialize variables
# reversed_string = ""
# index = len(string) - 1  # Start from the last character
#
# # Reverse the string using a while loop
# while index >= 0:
#     reversed_string += string[index]
#     index -= 1  # Move to the previous character
#
# # Print the reversed string
# print("Reversed String:", reversed_string)
# ```
#
# ### Explanation:
# - We start from the **last character** of the string.
# - We **append** each character to `reversed_string` in reverse order.
# - The **loop continues** until we reach the **first character**.
#
# 15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.
# -   # Get user input
# num = int(input("Enter a number: "))
#
# # Initialize factorial and counter
# factorial = 1
# i = num
#
# # Calculate factorial using a while loop
# while i > 0:
#     factorial *= i
#     i -= 1  # Decrease counter
#
# # Print the result
# print(f"Factorial of {num} is: {factorial}")
# Here's a Python program to calculate the **factorial** of a number using a **while loop**:
#
# ```python
# # Get user input
# num = int(input("Enter a number: "))
#
# # Initialize factorial and counter
# factorial = 1
# i = num
#
# # Calculate factorial using a while loop
# while i > 0:
#     factorial *= i
#     i -= 1  # Decrease counter
#
# # Print the result
# print(f"Factorial of {num} is: {factorial}")
# ```
#
# ### Explanation:
# 1. **Initialize `factorial = 1`** and set `i = num`.
# 2. Multiply `factorial` by `i`, then **decrease `i`** in each iteration.
# 3. **Loop stops** when `i` becomes `0`.
